# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
dat=pd.read_csv('/content/HR_comma_sep.csv')

# %%
dat.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# dtype: int64

# %%
dat.dropna()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dat.head(6)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# ...

# %%
dat.tail(6)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14993                0.76             0.83               6
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14993                   293                   6              0     1
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales salary
# ...

# %%
LR=LinearRegression()

# %%
ind=dat[['satisfaction_level','average_montly_hours','promotion_last_5years']]
dep=dat['salary']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
LE.fit(dep)
# Out:
# LabelEncoder()

# %%
enc=LE.transform(dep)

# %%
LE.fit(dep)
# Out:
# LabelEncoder()

# %%
dec=LE.fit_transform(dep)

# %%
LR.fit(ind, dec)
# Out:
# LinearRegression()

# %%
input_data = pd.DataFrame([[0.43, 250, 2]], columns=['satisfaction_level', 'average_montly_hours', 'promotion_last_5years'])
ans = LR.predict(input_data)
if ans[0] == 0:
    print(" the worker will not continue with the company")
else:
    print("the worker will continue with the company")
# Out:
# the worker will continue with the company
